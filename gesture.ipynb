# %%
# !wget https://www.gti.ssr.upm.es/data/Data/Downloads/HandGestureDatabase/set_1.rar
# Out:
# --2020-02-07 09:42:53--  https://www.gti.ssr.upm.es/data/Data/Downloads/HandGestureDatabase/set_1.rar
# Resolving www.gti.ssr.upm.es (www.gti.ssr.upm.es)... 138.4.32.2
# Connecting to www.gti.ssr.upm.es (www.gti.ssr.upm.es)|138.4.32.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5356942227 (5.0G) [application/rar]
# Saving to: ‘set_1.rar’
#
# set_1.rar           100%[===================>]   4.99G  9.24MB/s    in 6m 8s
#
# 2020-02-07 09:49:01 (13.9 MB/s) - ‘set_1.rar’ saved [5356942227/5356942227]

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install rarfile
# Out:
# ...
#      |████████████████████████████████| 122kB 2.8MB/s
# ...
#   Created wheel for rarfile: filename=rarfile-3.1-cp36-none-any.whl size=24908 sha256=c85449462d65228136f69f720d6e588babe0f6545f7a76da04606a1ec5c92409
#   Stored in directory: /root/.cache/pip/wheels/23/3c/c8/0215b6a5079492eff3be3f545ae0b0c4a66734c35c9e444eac
# Successfully built rarfile
# ...

# %%
from distutils.dir_util import copy_tree

# %%
copy_tree("/content/gesture", "/content/gdrive/My Drive/gesture_set1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23eec92ff558> in <module>()
# ----> 1 copy_tree("/content/gesture", "/content/gdrive/My Drive/gesture_set1")
#
# NameError: name 'copy_tree' is not defined

# %%
name=[]
for i in os.listdir("/content/gesture"):
  name.append(i)

# %%
count=0
for i in os.listdir("/content/gdrive/My Drive"):
  if i in name:
    count=count+1
    os.remove("/content/gdrive/My Drive/"+i)
print(count)
# Out:
# 0

# %%
drive.flush_and_unmount()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-7e7fc67cc157> in <module>()
# ----> 1 drive.flush_and_unmount()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in flush_and_unmount(timeout_ms)
#      83                         stdout=_subprocess.PIPE,
#      84                         stderr=_subprocess.PIPE)
# ---> 85   out, err = p.communicate()
#      86   if mount._DEBUG:  # pylint:disable=protected-access
#      87     print('flush_and_unmount: out: {}\nerr: {}'.format(out, err))
#
# /usr/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     861
#     862             try:
# --> 863                 stdout, stderr = self._communicate(input, endtime, timeout)
#     864             finally:
#     865                 self._communication_started = True
#
# ...

# %%
drive.mount("/content/gdrive")

# %%
import shutil
shutil.copy("/content/set_1.rar","/content/gdrive/My Drive")
# Out:
# '/content/gdrive/My Drive/set_1.rar'

# %%
# !unrar e "/content/set_1.rar" "/content/gesture"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/set_1.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
count=0 
for i in os.listdir("/content/gesture"):
  count=count+1
print(count)
# Out:
# 3145

# %%
import matplotlib.pyplot as plt
import cv2

# %%
import shutil

# %%
shutil.copytree("/content/gdrive/My Drive/gesture_set1","content")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2524eee15a57> in <module>()
# ----> 1 shutil.copytree("/content/gdrive/My Drive/gesture_set1","content")
#
# /usr/lib/python3.6/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks)
#     349             else:
#     350                 # Will raise a SpecialFileError for unsupported file types
# --> 351                 copy_function(srcname, dstname)
#     352         # catch the Error from the recursive copytree so that we can
#     353         # continue with other files
#
# /usr/lib/python3.6/shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
# ...

# %%
# !wget http://www-prima.inrialpes.fr/FGnet/data/03-Pointing/database
# Out:
# --2020-02-09 15:47:07--  http://www-prima.inrialpes.fr/FGnet/data/03-Pointing/database
# Resolving www-prima.inrialpes.fr (www-prima.inrialpes.fr)... 194.199.16.25
# Connecting to www-prima.inrialpes.fr (www-prima.inrialpes.fr)|194.199.16.25|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://www-prima.inrialpes.fr/FGnet/data/03-Pointing/database/ [following]
# --2020-02-09 15:47:07--  http://www-prima.inrialpes.fr/FGnet/data/03-Pointing/database/
# Reusing existing connection to www-prima.inrialpes.fr:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 964 [text/html]
# Saving to: ‘database’
#
# database            100%[===================>]     964  --.-KB/s    in 0s
#
# 2020-02-09 15:47:07 (199 MB/s) - ‘database’ saved [964/964]

# %%
# !wget https://www.idiap.ch/resource/gestures/data/shp_marcel_train.tar.gz
# Out:
# --2020-02-09 15:51:44--  https://www.idiap.ch/resource/gestures/data/shp_marcel_train.tar.gz
# Resolving www.idiap.ch (www.idiap.ch)... 192.33.221.201
# Connecting to www.idiap.ch (www.idiap.ch)|192.33.221.201|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100519094 (96M) [application/x-gzip]
# Saving to: ‘shp_marcel_train.tar.gz’
#
# shp_marcel_train.ta 100%[===================>]  95.86M  11.5MB/s    in 8.8s
#
# 2020-02-09 15:51:54 (10.9 MB/s) - ‘shp_marcel_train.tar.gz’ saved [100519094/100519094]

# %%
shutil.rmtree("content")

# %%
import os
os.mkdir("/content/gesture")

# %%
# !unzip "/content/shp_marcel_train.tar.gz" -d "/content/gesture"
# Out:
# Archive:  /content/shp_marcel_train.tar.gz
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/shp_marcel_train.tar.gz or
#         /content/shp_marcel_train.tar.gz.zip, and cannot find /content/shp_marcel_train.tar.gz.ZIP, period.

# %%
# !tar -xvf /content/shp_marcel_train.tar.gz
# Out:
# Marcel-Train/A/
# Marcel-Train/A/A-train0003.ppm
# Marcel-Train/A/A-train0004.ppm
# Marcel-Train/A/A-train0005.ppm
# Marcel-Train/A/A-train0006.ppm
# Marcel-Train/A/A-train0007.ppm
# Marcel-Train/A/A-train0008.ppm
# Marcel-Train/A/A-train0009.ppm
# Marcel-Train/A/A-train0010.ppm
# Marcel-Train/A/A-train0011.ppm
# Marcel-Train/A/A-train0012.ppm
# Marcel-Train/A/A-train0013.ppm
# Marcel-Train/A/A-train0014.ppm
# Marcel-Train/A/A-train0015.ppm
# Marcel-Train/A/A-train0016.ppm
# Marcel-Train/A/A-train0017.ppm
# Marcel-Train/A/A-train0018.ppm
# Marcel-Train/A/A-train0019.ppm
# Marcel-Train/A/A-train0020.ppm
# Marcel-Train/A/A-train0021.ppm
# Marcel-Train/A/A-train0022.ppm
# Marcel-Train/A/A-train0023.ppm
# Marcel-Train/A/A-train0024.ppm
# Marcel-Train/A/A-train0025.ppm
# Marcel-Train/A/A-train0026.ppm
# Marcel-Train/A/A-train0027.ppm
# Marcel-Train/A/A-train0028.ppm
# Marcel-Train/A/A-train0029.ppm
# Marcel-Train/A/A-train0030.ppm
# Marcel-Train/A/A-train0031.ppm
# ...

# %%
# !wget https://www.idiap.ch/resource/gestures/data/dhp_marcel.tar.gz
# Out:
# --2020-02-09 15:56:50--  https://www.idiap.ch/resource/gestures/data/dhp_marcel.tar.gz
# Resolving www.idiap.ch (www.idiap.ch)... 192.33.221.201
# Connecting to www.idiap.ch (www.idiap.ch)|192.33.221.201|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41434135 (40M) [application/x-gzip]
# Saving to: ‘dhp_marcel.tar.gz’
#
# dhp_marcel.tar.gz   100%[===================>]  39.51M  9.33MB/s    in 4.5s
#
# 2020-02-09 15:56:55 (8.88 MB/s) - ‘dhp_marcel.tar.gz’ saved [41434135/41434135]

# %%
# !tar -xvf /content/dhp_marcel.tar.gz
# Out:
# dhp_marcel/Clic/
# dhp_marcel/Clic/Seq9/
# dhp_marcel/Clic/Seq9/Seq9_Image1.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image2.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image3.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image4.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image5.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image6.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image7.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image8.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image9.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image10.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image11.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image12.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image13.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image14.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image15.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image16.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image17.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image18.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image19.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image20.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image21.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image22.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image23.pnm
# dhp_marcel/Clic/Seq9/Seq9_Image24.pnm
# ...
